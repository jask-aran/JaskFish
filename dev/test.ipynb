# %%
import chess

# %%
board = chess.Board()
board
# Out:
# Board('rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1')

# %%
board.push_san("e4")
board
# Out:
# Board('rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR b KQkq - 0 1')

# %%
list(board.legal_moves)
# Out:
# [Move.from_uci('g8h6'),
#  Move.from_uci('g8f6'),
#  Move.from_uci('b8c6'),
#  Move.from_uci('b8a6'),
#  Move.from_uci('h7h6'),
#  Move.from_uci('g7g6'),
#  Move.from_uci('f7f6'),
#  Move.from_uci('e7e6'),
#  Move.from_uci('d7d6'),
#  Move.from_uci('c7c6'),
#  Move.from_uci('b7b6'),
#  Move.from_uci('a7a6'),
#  Move.from_uci('h7h5'),
#  Move.from_uci('g7g5'),
#  Move.from_uci('f7f5'),
#  Move.from_uci('e7e5'),
#  Move.from_uci('d7d5'),
#  Move.from_uci('c7c5'),
#  Move.from_uci('b7b5'),
#  Move.from_uci('a7a5')]

# %%
print(type(chess.E2))
print(board.fen())
# Out:
# <class 'int'>
# rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR b KQkq - 0 1

# %%
chess.svg.board(board=board, arrows=[(chess.G1, chess.F3)], size=400, lastmove=board.peek())
# Out:
# '<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" version="1.2" baseProfile="tiny" viewBox="0 0 390 390" width="400" height="400"><desc><pre>r n b q k b n r\np p p p p p p p\n. . . . . . . .\n. . . . . . . .\n. . . . P . . .\n. . . . . . . .\nP P P P . P P P\nR N B Q K B N R</pre></desc><defs><g id="white-pawn" class="white pawn"><path d="M22.5 9c-2.21 0-4 1.79-4 4 0 .89.29 1.71.78 2.38C17.33 16.5 16 18.59 16 21c0 2.03.94 3.84 2.41 5.03-3 1.06-7.41 5.55-7.41 13.47h23c0-7.92-4.41-12.41-7.41-13.47 1.47-1.19 2.41-3 2.41-5.03 0-2.41-1.33-4.5-3.28-5.62.49-.67.78-1.49.78-2.38 0-2.21-1.79-4-4-4z" fill="#fff" stroke="#000" stroke-width="1.5" stroke-linecap="round" /></g><g id="white-knight" class="white knight" fill="none" fill-rule="evenodd" stroke="#000" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"><path d="M 22,10 C 32.5,11 38.5,18 38,39 L 15,39 C 15,30 25,32.5 23,18" style="fill:#ffffff; stroke:#000000;" /><path d="M 24,18 C 24.38,20
# ...

# %%
import cairosvg
from PIL import Image, ImageTk
from io import BytesIO

svg_string = chess.svg.board(board=board, lastmove=board.peek() if board.move_stack else None, size=500)
png_image = cairosvg.svg2png(bytestring=svg_string.encode('utf-8'))

image = Image.open(BytesIO(png_image))
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x500>

# %%
piece_position = chess.E1
piece_position
# Out:
# 4
